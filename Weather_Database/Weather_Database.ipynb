# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an endpoint URL for a city.(London)
london_url = url + "&q=" + "London"

# %%
# Make a 'Get' request for the city weather.(London)
london_weather = requests.get(london_url)
london_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.(London)
london_weather.text
# Out:
# '{"coord":{"lon":-0.1257,"lat":51.5085},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}],"base":"stations","main":{"temp":79.93,"feels_like":79.93,"temp_min":75.7,"temp_max":84.99,"pressure":1027,"humidity":46},"visibility":10000,"wind":{"speed":16.11,"deg":110},"clouds":{"all":60},"dt":1660064283,"sys":{"type":2,"id":268730,"country":"GB","sunrise":1660019780,"sunset":1660073750},"timezone":3600,"id":2643743,"name":"London","cod":200}'

# %%
# Get the JSON text of the 'Get' request.(London)
london_weather.json()
# Out:
# {'coord': {'lon': -0.1257, 'lat': 51.5085},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 79.93,
#   'feels_like': 79.93,
#   'temp_min': 75.7,
#   'temp_max': 84.99,
#   'pressure': 1027,
#   'humidity': 46},
#  'visibility': 10000,
#  'wind': {'speed': 16.11, 'deg': 110},
#  'clouds': {'all': 60},
#  'dt': 1660064283,
#  'sys': {'type': 2,
#   'id': 268730,
#   'country': 'GB',
#   'sunrise': 1660019780,
#   'sunset': 1660073750},
#  'timezone': 3600,
#  'id': 2643743,
#  'name': 'London',
#  'cod': 200}

# %%
london_current_description = london_weather.json()["weather"][0]["description"]
london_name = london_weather.json()["name"]
london_current_description
london_name
# Out:
# 'London'

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_name = city_weather["name"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_description = city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city_name,
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dikson
# Processing Record 2 of Set 1 | hilo
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | oxapampa
# Processing Record 5 of Set 1 | saskylakh
# Processing Record 6 of Set 1 | cidreira
# Processing Record 7 of Set 1 | upernavik
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | hithadhoo
# Processing Record 10 of Set 1 | narsaq
# Processing Record 11 of Set 1 | brae
# Processing Record 12 of Set 1 | cape town
# Processing Record 13 of Set 1 | barrow
# Processing Record 14 of Set 1 | muros
# Processing Record 15 of Set 1 | marsabit
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | lusambo
# Processing Record 18 of Set 1 | boa vista
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | westport
# Processing Record 22 of Set 1 | vila franca do campo
# Processing Record 23 of Set 1 | airai
# Processing Record 24 of Set 1 | thompson
# Processing Record 25 of Set 1 | paytug
# City not found. Skipping...
# Processing Record 26 of Set 1 | palana
# Processing Record 27 of Set 1 | hit
# Processing Record 28 of Set 1 | ashland
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | akhmeta
# Processing Record 31 of Set 1 | hobart
# Processing Record 32 of Set 1 | semenivka
# Processing Record 33 of Set 1 | longyearbyen
# Processing Record 34 of Set 1 | aktau
# Processing Record 35 of Set 1 | pangnirtung
# Processing Record 36 of Set 1 | yellowknife
# Processing Record 37 of Set 1 | kapaa
# Processing Record 38 of Set 1 | saldanha
# Processing Record 39 of Set 1 | port alfred
# Processing Record 40 of Set 1 | port-cartier
# Processing Record 41 of Set 1 | naze
# Processing Record 42 of Set 1 | fairbanks
# Processing Record 43 of Set 1 | bengkulu
# Processing Record 44 of Set 1 | raychikhinsk
# Processing Record 45 of Set 1 | verkhoyansk
# Processing Record 46 of Set 1 | butaritari
# Processing Record 47 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 1 | georgetown
# Processing Record 49 of Set 1 | poum
# Processing Record 50 of Set 1 | touros
# Processing Record 1 of Set 2 | goderich
# Processing Record 2 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 3 of Set 2 | sorland
# Processing Record 4 of Set 2 | codrington
# Processing Record 5 of Set 2 | joshimath
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 2 | nikolskoye
# Processing Record 9 of Set 2 | tuktoyaktuk
# Processing Record 10 of Set 2 | punta arenas
# Processing Record 11 of Set 2 | mataura
# Processing Record 12 of Set 2 | carnarvon
# Processing Record 13 of Set 2 | camana
# Processing Record 14 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 2 | perbaungan
# Processing Record 16 of Set 2 | east london
# Processing Record 17 of Set 2 | sitka
# Processing Record 18 of Set 2 | aromashevo
# Processing Record 19 of Set 2 | fayaoue
# Processing Record 20 of Set 2 | alofi
# Processing Record 21 of Set 2 | iqaluit
# Processing Record 22 of Set 2 | pevek
# Processing Record 23 of Set 2 | uruacu
# Processing Record 24 of Set 2 | hermanus
# Processing Record 25 of Set 2 | cabedelo
# Processing Record 26 of Set 2 | sao jose da coroa grande
# Processing Record 27 of Set 2 | lorengau
# Processing Record 28 of Set 2 | arraial do cabo
# Processing Record 29 of Set 2 | basar
# Processing Record 30 of Set 2 | puerto ayora
# Processing Record 31 of Set 2 | zhengjiatun
# Processing Record 32 of Set 2 | oktyabrskiy
# Processing Record 33 of Set 2 | riva
# Processing Record 34 of Set 2 | amapa
# Processing Record 35 of Set 2 | avarua
# Processing Record 36 of Set 2 | balkhash
# Processing Record 37 of Set 2 | isangel
# Processing Record 38 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 39 of Set 2 | ixtapa
# Processing Record 40 of Set 2 | geraldton
# Processing Record 41 of Set 2 | raga
# Processing Record 42 of Set 2 | kailua
# Processing Record 43 of Set 2 | severo-kurilsk
# Processing Record 44 of Set 2 | kitimat
# Processing Record 45 of Set 2 | lebu
# Processing Record 46 of Set 2 | beian
# Processing Record 47 of Set 2 | chuy
# Processing Record 48 of Set 2 | bahia honda
# Processing Record 49 of Set 2 | qaanaaq
# Processing Record 50 of Set 2 | gazojak
# Processing Record 1 of Set 3 | saint-philippe
# Processing Record 2 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 3 of Set 3 | zinder
# Processing Record 4 of Set 3 | luganville
# Processing Record 5 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 6 of Set 3 | vetluzhskiy
# Processing Record 7 of Set 3 | tiksi
# Processing Record 8 of Set 3 | san ignacio
# Processing Record 9 of Set 3 | stargard szczecinski
# Processing Record 10 of Set 3 | hasaki
# Processing Record 11 of Set 3 | tasiilaq
# Processing Record 12 of Set 3 | juifang
# City not found. Skipping...
# Processing Record 13 of Set 3 | quelimane
# Processing Record 14 of Set 3 | mormugao
# Processing Record 15 of Set 3 | whitehorse
# Processing Record 16 of Set 3 | bredasdorp
# Processing Record 17 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 18 of Set 3 | palmer
# Processing Record 19 of Set 3 | castro
# Processing Record 20 of Set 3 | mehamn
# Processing Record 21 of Set 3 | new norfolk
# Processing Record 22 of Set 3 | kaitangata
# Processing Record 23 of Set 3 | sola
# Processing Record 24 of Set 3 | cockburn town
# Processing Record 25 of Set 3 | torbay
# Processing Record 26 of Set 3 | saint-pierre
# Processing Record 27 of Set 3 | yar-sale
# Processing Record 28 of Set 3 | voh
# Processing Record 29 of Set 3 | ancud
# Processing Record 30 of Set 3 | slawno
# Processing Record 31 of Set 3 | coquimbo
# Processing Record 32 of Set 3 | atuona
# Processing Record 33 of Set 3 | tawkar
# City not found. Skipping...
# Processing Record 34 of Set 3 | russell
# Processing Record 35 of Set 3 | cherskiy
# Processing Record 36 of Set 3 | cassilandia
# Processing Record 37 of Set 3 | yemtsa
# Processing Record 38 of Set 3 | straldza
# City not found. Skipping...
# Processing Record 39 of Set 3 | mana
# Processing Record 40 of Set 3 | nelidovo
# Processing Record 41 of Set 3 | taltal
# Processing Record 42 of Set 3 | grajau
# Processing Record 43 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 3 | meulaboh
# Processing Record 45 of Set 3 | vanimo
# Processing Record 46 of Set 3 | guerrero negro
# Processing Record 47 of Set 3 | kodiak
# Processing Record 48 of Set 3 | plettenberg bay
# Processing Record 49 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 3 | lagoa
# Processing Record 1 of Set 4 | washington
# Processing Record 2 of Set 4 | mar del plata
# Processing Record 3 of Set 4 | evensk
# Processing Record 4 of Set 4 | hambantota
# Processing Record 5 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 4 | razole
# Processing Record 7 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 8 of Set 4 | toamasina
# Processing Record 9 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 4 | port hedland
# Processing Record 11 of Set 4 | pochutla
# Processing Record 12 of Set 4 | marawi
# Processing Record 13 of Set 4 | erdenet
# Processing Record 14 of Set 4 | praia
# Processing Record 15 of Set 4 | port-de-paix
# City not found. Skipping...
# Processing Record 16 of Set 4 | tigre
# Processing Record 17 of Set 4 | maceio
# Processing Record 18 of Set 4 | mayo
# Processing Record 19 of Set 4 | talaya
# Processing Record 20 of Set 4 | soe
# Processing Record 21 of Set 4 | chokurdakh
# Processing Record 22 of Set 4 | flinders
# Processing Record 23 of Set 4 | gat
# Processing Record 24 of Set 4 | fort nelson
# Processing Record 25 of Set 4 | soyo
# Processing Record 26 of Set 4 | erenhot
# Processing Record 27 of Set 4 | kurobe
# City not found. Skipping...
# Processing Record 28 of Set 4 | lompoc
# Processing Record 29 of Set 4 | pedernales
# Processing Record 30 of Set 4 | hamilton
# Processing Record 31 of Set 4 | faanui
# Processing Record 32 of Set 4 | saint-augustin
# Processing Record 33 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 34 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 4 | wewak
# Processing Record 36 of Set 4 | ribeira grande
# Processing Record 37 of Set 4 | tual
# Processing Record 38 of Set 4 | rantepao
# Processing Record 39 of Set 4 | khatanga
# Processing Record 40 of Set 4 | caxito
# Processing Record 41 of Set 4 | norrtalje
# Processing Record 42 of Set 4 | aswan
# Processing Record 43 of Set 4 | porto novo
# Processing Record 44 of Set 4 | mahebourg
# Processing Record 45 of Set 4 | bitlis
# Processing Record 46 of Set 4 | wuwei
# Processing Record 47 of Set 4 | whyalla
# Processing Record 48 of Set 4 | lota
# Processing Record 49 of Set 4 | upata
# Processing Record 50 of Set 4 | saint anthony
# Processing Record 1 of Set 5 | lapua
# Processing Record 2 of Set 5 | rafai
# Processing Record 3 of Set 5 | honningsvag
# Processing Record 4 of Set 5 | mattru
# Processing Record 5 of Set 5 | saint george
# Processing Record 6 of Set 5 | fortuna
# Processing Record 7 of Set 5 | tromso
# Processing Record 8 of Set 5 | lucapa
# Processing Record 9 of Set 5 | jalu
# Processing Record 10 of Set 5 | fukue
# Processing Record 11 of Set 5 | klaksvik
# Processing Record 12 of Set 5 | salalah
# Processing Record 13 of Set 5 | kinanah
# City not found. Skipping...
# Processing Record 14 of Set 5 | hounde
# Processing Record 15 of Set 5 | tuatapere
# Processing Record 16 of Set 5 | rocha
# Processing Record 17 of Set 5 | baijiantan
# Processing Record 18 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 5 | marzuq
# Processing Record 20 of Set 5 | sao joao da ponte
# Processing Record 21 of Set 5 | constitucion
# Processing Record 22 of Set 5 | aklavik
# Processing Record 23 of Set 5 | yian
# City not found. Skipping...
# Processing Record 24 of Set 5 | novikovo
# Processing Record 25 of Set 5 | bandarbeyla
# Processing Record 26 of Set 5 | provideniya
# Processing Record 27 of Set 5 | mildura
# Processing Record 28 of Set 5 | vestmannaeyjar
# Processing Record 29 of Set 5 | nouadhibou
# Processing Record 30 of Set 5 | gunnaur
# Processing Record 31 of Set 5 | husainabad
# Processing Record 32 of Set 5 | beroroha
# Processing Record 33 of Set 5 | moree
# Processing Record 34 of Set 5 | swan hill
# Processing Record 35 of Set 5 | nanortalik
# Processing Record 36 of Set 5 | tabuk
# Processing Record 37 of Set 5 | karratha
# Processing Record 38 of Set 5 | belmonte
# Processing Record 39 of Set 5 | kilindoni
# Processing Record 40 of Set 5 | katsuura
# Processing Record 41 of Set 5 | sioux lookout
# Processing Record 42 of Set 5 | zhigansk
# Processing Record 43 of Set 5 | svetlogorsk
# Processing Record 44 of Set 5 | dwarka
# Processing Record 45 of Set 5 | kholmogory
# Processing Record 46 of Set 5 | crab hill
# City not found. Skipping...
# Processing Record 47 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 48 of Set 5 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 49 of Set 5 | kavieng
# Processing Record 50 of Set 5 | gisborne
# Processing Record 1 of Set 6 | marsa matruh
# Processing Record 2 of Set 6 | kuching
# Processing Record 3 of Set 6 | malayal
# Processing Record 4 of Set 6 | chagoda
# Processing Record 5 of Set 6 | ballyshannon
# Processing Record 6 of Set 6 | chimbote
# Processing Record 7 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 8 of Set 6 | diamantino
# Processing Record 9 of Set 6 | camargo
# Processing Record 10 of Set 6 | strezhevoy
# Processing Record 11 of Set 6 | atherton
# Processing Record 12 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 6 | kushiro
# Processing Record 14 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 15 of Set 6 | norman wells
# Processing Record 16 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 17 of Set 6 | dudinka
# Processing Record 18 of Set 6 | guarapari
# Processing Record 19 of Set 6 | te anau
# Processing Record 20 of Set 6 | nishihara
# Processing Record 21 of Set 6 | xai-xai
# Processing Record 22 of Set 6 | coihaique
# Processing Record 23 of Set 6 | roald
# Processing Record 24 of Set 6 | haines junction
# Processing Record 25 of Set 6 | waingapu
# Processing Record 26 of Set 6 | oliveira
# Processing Record 27 of Set 6 | anloga
# Processing Record 28 of Set 6 | kieta
# Processing Record 29 of Set 6 | luderitz
# Processing Record 30 of Set 6 | burnie
# Processing Record 31 of Set 6 | tutin
# Processing Record 32 of Set 6 | atar
# Processing Record 33 of Set 6 | pushkar
# Processing Record 34 of Set 6 | puerto del rosario
# Processing Record 35 of Set 6 | clyde river
# Processing Record 36 of Set 6 | plouzane
# Processing Record 37 of Set 6 | bacuit
# City not found. Skipping...
# Processing Record 38 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 6 | bambous virieux
# Processing Record 40 of Set 6 | gangotri
# City not found. Skipping...
# Processing Record 41 of Set 6 | gazli
# Processing Record 42 of Set 6 | hereford
# Processing Record 43 of Set 6 | dingle
# Processing Record 44 of Set 6 | beloha
# Processing Record 45 of Set 6 | dustlik
# Processing Record 46 of Set 6 | arlit
# Processing Record 47 of Set 6 | algeciras
# Processing Record 48 of Set 6 | san quintin
# Processing Record 49 of Set 6 | the valley
# Processing Record 50 of Set 6 | la romana
# Processing Record 1 of Set 7 | victoria
# Processing Record 2 of Set 7 | sulurpeta
# City not found. Skipping...
# Processing Record 3 of Set 7 | nefteyugansk
# Processing Record 4 of Set 7 | bishop auckland
# Processing Record 5 of Set 7 | mabaruma
# Processing Record 6 of Set 7 | egvekinot
# Processing Record 7 of Set 7 | lancaster
# Processing Record 8 of Set 7 | champerico
# Processing Record 9 of Set 7 | tukrah
# Processing Record 10 of Set 7 | caravelas
# Processing Record 11 of Set 7 | pacific grove
# Processing Record 12 of Set 7 | nhulunbuy
# Processing Record 13 of Set 7 | padang
# Processing Record 14 of Set 7 | marrakesh
# Processing Record 15 of Set 7 | walvis bay
# Processing Record 16 of Set 7 | umm jarr
# City not found. Skipping...
# Processing Record 17 of Set 7 | namibe
# Processing Record 18 of Set 7 | kebemer
# City not found. Skipping...
# Processing Record 19 of Set 7 | demirci
# Processing Record 20 of Set 7 | south lake tahoe
# Processing Record 21 of Set 7 | banda aceh
# Processing Record 22 of Set 7 | panguipulli
# Processing Record 23 of Set 7 | kota belud
# Processing Record 24 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 7 | batagay-alyta
# Processing Record 26 of Set 7 | road town
# Processing Record 27 of Set 7 | manali
# Processing Record 28 of Set 7 | suntar
# Processing Record 29 of Set 7 | harper
# Processing Record 30 of Set 7 | esil
# Processing Record 31 of Set 7 | portland
# Processing Record 32 of Set 7 | semnan
# Processing Record 33 of Set 7 | saint-joseph
# Processing Record 34 of Set 7 | ambilobe
# Processing Record 35 of Set 7 | innisfail
# Processing Record 36 of Set 7 | alice springs
# Processing Record 37 of Set 7 | xiongshi
# City not found. Skipping...
# Processing Record 38 of Set 7 | leninskoye
# Processing Record 39 of Set 7 | mackenzie
# Processing Record 40 of Set 7 | rio gallegos
# Processing Record 41 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 7 | port lincoln
# Processing Record 43 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 44 of Set 7 | puerto suarez
# Processing Record 45 of Set 7 | vao
# Processing Record 46 of Set 7 | langarud
# Processing Record 47 of Set 7 | dunedin
# Processing Record 48 of Set 7 | kruisfontein
# Processing Record 49 of Set 7 | polis
# Processing Record 50 of Set 7 | dunga bunga
# Processing Record 1 of Set 8 | labuhan
# Processing Record 2 of Set 8 | lerwick
# Processing Record 3 of Set 8 | kitgum
# Processing Record 4 of Set 8 | buala
# Processing Record 5 of Set 8 | santa luzia
# Processing Record 6 of Set 8 | bonavista
# Processing Record 7 of Set 8 | lebanon
# Processing Record 8 of Set 8 | inirida
# Processing Record 9 of Set 8 | souillac
# Processing Record 10 of Set 8 | ponta do sol
# Processing Record 11 of Set 8 | rorvik
# Processing Record 12 of Set 8 | los llanos de aridane
# Processing Record 13 of Set 8 | port elizabeth
# Processing Record 14 of Set 8 | grevesmuhlen
# Processing Record 15 of Set 8 | quatre cocos
# Processing Record 16 of Set 8 | asau
# Processing Record 17 of Set 8 | talcahuano
# Processing Record 18 of Set 8 | tacuarembo
# Processing Record 19 of Set 8 | porto santo
# Processing Record 20 of Set 8 | chichigalpa
# Processing Record 21 of Set 8 | adrar
# Processing Record 22 of Set 8 | san cristobal
# Processing Record 23 of Set 8 | susehri
# Processing Record 24 of Set 8 | lavrentiya
# Processing Record 25 of Set 8 | ponta delgada
# Processing Record 26 of Set 8 | pimentel
# Processing Record 27 of Set 8 | ajaccio
# Processing Record 28 of Set 8 | chabahar
# Processing Record 29 of Set 8 | santa fe
# Processing Record 30 of Set 8 | fare
# Processing Record 31 of Set 8 | mayumba
# Processing Record 32 of Set 8 | san patricio
# Processing Record 33 of Set 8 | luocheng
# Processing Record 34 of Set 8 | margate
# Processing Record 35 of Set 8 | marevo
# Processing Record 36 of Set 8 | lushunkou
# City not found. Skipping...
# Processing Record 37 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 8 | ornskoldsvik
# Processing Record 39 of Set 8 | bure
# Processing Record 40 of Set 8 | kasane
# Processing Record 41 of Set 8 | boyolangu
# Processing Record 42 of Set 8 | bethel
# Processing Record 43 of Set 8 | arman
# Processing Record 44 of Set 8 | solnechnyy
# Processing Record 45 of Set 8 | port hardy
# Processing Record 46 of Set 8 | san policarpo
# Processing Record 47 of Set 8 | khash
# Processing Record 48 of Set 8 | esperance
# Processing Record 49 of Set 8 | severnyy
# Processing Record 50 of Set 8 | vanavara
# Processing Record 1 of Set 9 | peleduy
# Processing Record 2 of Set 9 | banikoara
# Processing Record 3 of Set 9 | dicabisagan
# Processing Record 4 of Set 9 | natalio
# Processing Record 5 of Set 9 | lindsay
# Processing Record 6 of Set 9 | zhaoyang
# Processing Record 7 of Set 9 | mouzakion
# City not found. Skipping...
# Processing Record 8 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 9 of Set 9 | leningradskiy
# Processing Record 10 of Set 9 | banjarmasin
# Processing Record 11 of Set 9 | inhambane
# Processing Record 12 of Set 9 | biltine
# Processing Record 13 of Set 9 | college
# Processing Record 14 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 9 | bathsheba
# Processing Record 16 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 9 | gelibolu
# Processing Record 18 of Set 9 | den helder
# Processing Record 19 of Set 9 | szczecinek
# Processing Record 20 of Set 9 | lebedinyy
# Processing Record 21 of Set 9 | bengbu
# Processing Record 22 of Set 9 | marfino
# Processing Record 23 of Set 9 | hudson bay
# Processing Record 24 of Set 9 | mantua
# Processing Record 25 of Set 9 | sao joao da barra
# Processing Record 26 of Set 9 | benghazi
# Processing Record 27 of Set 9 | shingu
# Processing Record 28 of Set 9 | ostrovnoy
# Processing Record 29 of Set 9 | columbus
# Processing Record 30 of Set 9 | cayenne
# Processing Record 31 of Set 9 | nyurba
# Processing Record 32 of Set 9 | oulainen
# Processing Record 33 of Set 9 | naberera
# Processing Record 34 of Set 9 | shediac
# Processing Record 35 of Set 9 | lokosovo
# Processing Record 36 of Set 9 | mount gambier
# Processing Record 37 of Set 9 | koupela
# Processing Record 38 of Set 9 | south yuba city
# Processing Record 39 of Set 9 | kanturk
# Processing Record 40 of Set 9 | rolla
# Processing Record 41 of Set 9 | formosa
# Processing Record 42 of Set 9 | kingaroy
# Processing Record 43 of Set 9 | tiarei
# Processing Record 44 of Set 9 | uvinza
# Processing Record 45 of Set 9 | mahon
# Processing Record 46 of Set 9 | maarianhamina
# Processing Record 47 of Set 9 | katherine
# Processing Record 48 of Set 9 | ewa beach
# Processing Record 49 of Set 9 | nunoa
# Processing Record 50 of Set 9 | sangmelima
# Processing Record 1 of Set 10 | eydhafushi
# Processing Record 2 of Set 10 | sao filipe
# Processing Record 3 of Set 10 | gravdal
# Processing Record 4 of Set 10 | glendive
# Processing Record 5 of Set 10 | kudahuvadhoo
# Processing Record 6 of Set 10 | olafsvik
# Processing Record 7 of Set 10 | bereznik
# Processing Record 8 of Set 10 | nakapiripirit
# Processing Record 9 of Set 10 | ahipara
# Processing Record 10 of Set 10 | yatou
# Processing Record 11 of Set 10 | san blas
# Processing Record 12 of Set 10 | pinar del rio
# Processing Record 13 of Set 10 | kysyl-syr
# Processing Record 14 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 10 | purpe
# Processing Record 16 of Set 10 | mendi
# Processing Record 17 of Set 10 | jibuti
# Processing Record 18 of Set 10 | houma
# Processing Record 19 of Set 10 | rajauri
# Processing Record 20 of Set 10 | rio verde de mato grosso
# Processing Record 21 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 10 | kasongo-lunda
# Processing Record 23 of Set 10 | dongning
# Processing Record 24 of Set 10 | priiskovyy
# Processing Record 25 of Set 10 | bima
# Processing Record 26 of Set 10 | iwanai
# Processing Record 27 of Set 10 | broome
# Processing Record 28 of Set 10 | kishi
# Processing Record 29 of Set 10 | ondjiva
# Processing Record 30 of Set 10 | griffith
# Processing Record 31 of Set 10 | ramsey
# Processing Record 32 of Set 10 | ferme-neuve
# Processing Record 33 of Set 10 | sao gabriel da cachoeira
# Processing Record 34 of Set 10 | atasu
# Processing Record 35 of Set 10 | grand-santi
# Processing Record 36 of Set 10 | buchanan
# Processing Record 37 of Set 10 | isla vista
# Processing Record 38 of Set 10 | port-gentil
# Processing Record 39 of Set 10 | taoudenni
# Processing Record 40 of Set 10 | husavik
# Processing Record 41 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 42 of Set 10 | camacha
# Processing Record 43 of Set 10 | bac lieu
# Processing Record 44 of Set 10 | port hawkesbury
# Processing Record 45 of Set 10 | kashi
# Processing Record 46 of Set 10 | charkhi dadri
# Processing Record 47 of Set 10 | puerto el triunfo
# Processing Record 48 of Set 10 | ayorou
# Processing Record 49 of Set 10 | deputatskiy
# Processing Record 50 of Set 10 | dawlatabad
# Processing Record 1 of Set 11 | winkler
# Processing Record 2 of Set 11 | palora
# Processing Record 3 of Set 11 | gimli
# Processing Record 4 of Set 11 | arvika
# Processing Record 5 of Set 11 | zeya
# Processing Record 6 of Set 11 | bassano
# Processing Record 7 of Set 11 | olhao
# Processing Record 8 of Set 11 | ballina
# Processing Record 9 of Set 11 | casian
# Processing Record 10 of Set 11 | ntcheu
# Processing Record 11 of Set 11 | drayton valley
# Processing Record 12 of Set 11 | opuwo
# Processing Record 13 of Set 11 | morant bay
# Processing Record 14 of Set 11 | kankon
# Processing Record 15 of Set 11 | saint-raymond
# Processing Record 16 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 11 | nerchinskiy zavod
# Processing Record 18 of Set 11 | uwayl
# City not found. Skipping...
# Processing Record 19 of Set 11 | khalkhal
# Processing Record 20 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 21 of Set 11 | bacolod
# Processing Record 22 of Set 11 | roswell
# Processing Record 23 of Set 11 | troitsko-pechorsk
# Processing Record 24 of Set 11 | sterling
# Processing Record 25 of Set 11 | emerald
# Processing Record 26 of Set 11 | wladyslawowo
# Processing Record 27 of Set 11 | sibolga
# Processing Record 28 of Set 11 | berlevag
# Processing Record 29 of Set 11 | lethem
# Processing Record 30 of Set 11 | monte patria
# Processing Record 31 of Set 11 | cabo san lucas
# Processing Record 32 of Set 11 | senneterre
# Processing Record 33 of Set 11 | gizo
# Processing Record 34 of Set 11 | la ronge
# Processing Record 35 of Set 11 | corrientes
# Processing Record 36 of Set 11 | pampierstad
# Processing Record 37 of Set 11 | shestakovo
# Processing Record 38 of Set 11 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 39 of Set 11 | ginir
# Processing Record 40 of Set 11 | avera
# Processing Record 41 of Set 11 | kanor
# Processing Record 42 of Set 11 | nelson bay
# Processing Record 43 of Set 11 | wonthaggi
# Processing Record 44 of Set 11 | victor harbor
# Processing Record 45 of Set 11 | hadejia
# Processing Record 46 of Set 11 | manzhouli
# Processing Record 47 of Set 11 | chapais
# Processing Record 48 of Set 11 | pisco
# Processing Record 49 of Set 11 | karla
# Processing Record 50 of Set 11 | acarau
# Processing Record 1 of Set 12 | talnakh
# Processing Record 2 of Set 12 | gamba
# Processing Record 3 of Set 12 | kavaratti
# Processing Record 4 of Set 12 | san jeronimo
# Processing Record 5 of Set 12 | oranjemund
# Processing Record 6 of Set 12 | greven
# Processing Record 7 of Set 12 | port blair
# Processing Record 8 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 9 of Set 12 | golden
# Processing Record 10 of Set 12 | bodoco
# City not found. Skipping...
# Processing Record 11 of Set 12 | richards bay
# Processing Record 12 of Set 12 | kattivakkam
# Processing Record 13 of Set 12 | keelung
# Processing Record 14 of Set 12 | olenino
# Processing Record 15 of Set 12 | shangrao
# Processing Record 16 of Set 12 | constantine
# Processing Record 17 of Set 12 | alta floresta
# Processing Record 18 of Set 12 | faya
# Processing Record 19 of Set 12 | collie
# Processing Record 20 of Set 12 | oktyabrskoye
# Processing Record 21 of Set 12 | dembi dolo
# Processing Record 22 of Set 12 | boende
# Processing Record 23 of Set 12 | verkh-usugli
# Processing Record 24 of Set 12 | chesma
# Processing Record 25 of Set 12 | ibra
# Processing Record 26 of Set 12 | amarpur
# Processing Record 27 of Set 12 | batemans bay
# Processing Record 28 of Set 12 | kamina
# Processing Record 29 of Set 12 | ylivieska
# Processing Record 30 of Set 12 | zyryanka
# Processing Record 31 of Set 12 | forestville
# Processing Record 32 of Set 12 | esqueda
# Processing Record 33 of Set 12 | grafton
# Processing Record 34 of Set 12 | hofn
# Processing Record 35 of Set 12 | freeport
# Processing Record 36 of Set 12 | verkhoturye
# Processing Record 37 of Set 12 | hokitika
# Processing Record 38 of Set 12 | salta
# Processing Record 39 of Set 12 | korla
# Processing Record 40 of Set 12 | yerbogachen
# Processing Record 41 of Set 12 | bartica
# Processing Record 42 of Set 12 | colares
# Processing Record 43 of Set 12 | thohoyandou
# Processing Record 44 of Set 12 | ta khmau
# Processing Record 45 of Set 12 | muzhi
# Processing Record 46 of Set 12 | yinchuan
# Processing Record 47 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 48 of Set 12 | farmington
# Processing Record 49 of Set 12 | urengoy
# Processing Record 50 of Set 12 | lyuban
# Processing Record 1 of Set 13 | copiapo
# Processing Record 2 of Set 13 | penne
# Processing Record 3 of Set 13 | ilulissat
# Processing Record 4 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 5 of Set 13 | livingston
# Processing Record 6 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 7 of Set 13 | safaqis
# City not found. Skipping...
# Processing Record 8 of Set 13 | keetmanshoop
# Processing Record 9 of Set 13 | papasquiaro
# City not found. Skipping...
# Processing Record 10 of Set 13 | chapada dos guimaraes
# Processing Record 11 of Set 13 | mount isa
# Processing Record 12 of Set 13 | sulangan
# Processing Record 13 of Set 13 | am timan
# Processing Record 14 of Set 13 | matadi
# Processing Record 15 of Set 13 | beringovskiy
# Processing Record 16 of Set 13 | atbasar
# Processing Record 17 of Set 13 | kununurra
# Processing Record 18 of Set 13 | camocim
# Processing Record 19 of Set 13 | las lomas
# Processing Record 20 of Set 13 | japura
# Processing Record 21 of Set 13 | brainerd
# Processing Record 22 of Set 13 | dongsheng
# Processing Record 23 of Set 13 | huntsville
# Processing Record 24 of Set 13 | paamiut
# Processing Record 25 of Set 13 | pangoa
# Processing Record 26 of Set 13 | stokmarknes
# Processing Record 27 of Set 13 | inta
# Processing Record 28 of Set 13 | samana
# Processing Record 29 of Set 13 | half moon bay
# Processing Record 30 of Set 13 | kampar
# Processing Record 31 of Set 13 | kalmunai
# Processing Record 32 of Set 13 | beyneu
# Processing Record 33 of Set 13 | saint-avertin
# Processing Record 34 of Set 13 | komsomolskiy
# Processing Record 35 of Set 13 | zonguldak
# Processing Record 36 of Set 13 | kijang
# Processing Record 37 of Set 13 | casselman
# Processing Record 38 of Set 13 | ambon
# Processing Record 39 of Set 13 | lugovoy
# Processing Record 40 of Set 13 | yanam
# Processing Record 41 of Set 13 | kawalu
# Processing Record 42 of Set 13 | yabrud
# Processing Record 43 of Set 13 | tarakan
# Processing Record 44 of Set 13 | pauini
# Processing Record 45 of Set 13 | bonham
# Processing Record 46 of Set 13 | porto walter
# Processing Record 47 of Set 13 | blagoyevo
# Processing Record 48 of Set 13 | itacarambi
# Processing Record 49 of Set 13 | durban
# Processing Record 50 of Set 13 | sao gotardo
# Processing Record 1 of Set 14 | dhuburi
# Processing Record 2 of Set 14 | mastic beach
# Processing Record 3 of Set 14 | palmares do sul
# Processing Record 4 of Set 14 | araouane
# Processing Record 5 of Set 14 | lishan
# Processing Record 6 of Set 14 | ipilan
# Processing Record 7 of Set 14 | la rioja
# Processing Record 8 of Set 14 | port macquarie
# Processing Record 9 of Set 14 | lakes entrance
# Processing Record 10 of Set 14 | sodertalje
# City not found. Skipping...
# Processing Record 11 of Set 14 | mitu
# Processing Record 12 of Set 14 | mikhaylovka
# Processing Record 13 of Set 14 | leshukonskoye
# Processing Record 14 of Set 14 | yarada
# Processing Record 15 of Set 14 | novyy svit
# Processing Record 16 of Set 14 | maloy
# Processing Record 17 of Set 14 | ternate
# Processing Record 18 of Set 14 | waipawa
# Processing Record 19 of Set 14 | ust-tsilma
# Processing Record 20 of Set 14 | laguna
# Processing Record 21 of Set 14 | roebourne
# Processing Record 22 of Set 14 | bourail
# Processing Record 23 of Set 14 | derzhavinsk
# Processing Record 24 of Set 14 | puerto escondido
# Processing Record 25 of Set 14 | altamont
# Processing Record 26 of Set 14 | leh
# Processing Record 27 of Set 14 | thap than
# Processing Record 28 of Set 14 | bulawayo
# Processing Record 29 of Set 14 | wanaka
# Processing Record 30 of Set 14 | maryville
# Processing Record 31 of Set 14 | san luis
# Processing Record 32 of Set 14 | moerai
# Processing Record 33 of Set 14 | along
# Processing Record 34 of Set 14 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 35 of Set 14 | tazovskiy
# Processing Record 36 of Set 14 | tahoua
# Processing Record 37 of Set 14 | tiznit
# Processing Record 38 of Set 14 | lasa
# Processing Record 39 of Set 14 | thunder bay
# Processing Record 40 of Set 14 | baculin
# Processing Record 41 of Set 14 | wadi maliz
# Processing Record 42 of Set 14 | dukat
# Processing Record 43 of Set 14 | denpasar
# Processing Record 44 of Set 14 | tirumullaivasal
# Processing Record 45 of Set 14 | berdigestyakh
# Processing Record 46 of Set 14 | ayia galini
# Processing Record 47 of Set 14 | hay river
# Processing Record 48 of Set 14 | slave lake
# Processing Record 49 of Set 14 | gali
# Processing Record 50 of Set 14 | williams lake
# Processing Record 1 of Set 15 | bingol
# Processing Record 2 of Set 15 | hayden
# Processing Record 3 of Set 15 | abaza
# Processing Record 4 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 5 of Set 15 | puerto palomas
# Processing Record 6 of Set 15 | dzhebariki-khaya
# Processing Record 7 of Set 15 | furano
# Processing Record 8 of Set 15 | tuljapur
# Processing Record 9 of Set 15 | skagastrond
# City not found. Skipping...
# Processing Record 10 of Set 15 | louga
# Processing Record 11 of Set 15 | amlagora
# Processing Record 12 of Set 15 | altinopolis
# Processing Record 13 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 14 of Set 15 | quang ngai
# Processing Record 15 of Set 15 | vardo
# Processing Record 16 of Set 15 | ugoofaaru
# Processing Record 17 of Set 15 | kahului
# Processing Record 18 of Set 15 | sisimiut
# Processing Record 19 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 20 of Set 15 | san francisco
# Processing Record 21 of Set 15 | havoysund
# Processing Record 22 of Set 15 | murindo
# Processing Record 23 of Set 15 | antofagasta
# Processing Record 24 of Set 15 | port moresby
# Processing Record 25 of Set 15 | buariki
# City not found. Skipping...
# Processing Record 26 of Set 15 | nabire
# Processing Record 27 of Set 15 | kaeo
# Processing Record 28 of Set 15 | znamenskoye
# Processing Record 29 of Set 15 | kresek
# Processing Record 30 of Set 15 | najran
# Processing Record 31 of Set 15 | coahuayana
# Processing Record 32 of Set 15 | salinopolis
# Processing Record 33 of Set 15 | zelenoborsk
# Processing Record 34 of Set 15 | zhangjiakou
# Processing Record 35 of Set 15 | sechura
# Processing Record 36 of Set 15 | jizan
# Processing Record 37 of Set 15 | warri
# Processing Record 38 of Set 15 | villa maria
# Processing Record 39 of Set 15 | beboto
# Processing Record 40 of Set 15 | hami
# Processing Record 41 of Set 15 | sambava
# Processing Record 42 of Set 15 | kabare
# Processing Record 43 of Set 15 | nuuk
# Processing Record 44 of Set 15 | olden
# Processing Record 45 of Set 15 | port jervis
# Processing Record 46 of Set 15 | el alto
# Processing Record 47 of Set 15 | kirakira
# Processing Record 48 of Set 15 | tecate
# Processing Record 49 of Set 15 | togur
# Processing Record 50 of Set 15 | gzhatsk
# City not found. Skipping...
# Processing Record 1 of Set 16 | kyzyl-suu
# Processing Record 2 of Set 16 | unai
# Processing Record 3 of Set 16 | madimba
# Processing Record 4 of Set 16 | tungkang
# City not found. Skipping...
# Processing Record 5 of Set 16 | bosaso
# Processing Record 6 of Set 16 | talara
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 686

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Dikson      RU  73.5069   80.5464     42.22        93         100
# 1         Hilo      US  19.7297 -155.0900     82.27        90          74
# 2      Ushuaia      AR -54.8000  -68.3000     42.42        70           0
# 3     Oxapampa      PE -10.5775  -75.4017     67.24        78          88
# 4    Saskylakh      RU  71.9167  114.0833     50.61        88           6
# ..         ...     ...      ...       ...       ...       ...         ...
# 681  Kyzyl-Suu      KG  42.3414   78.0056     63.37        64           3
# 682       Unaí      BR -16.3575  -46.9061     91.62        25          22
# 683    Madimba      TZ -10.4000   40.3333     74.39        71          80
# 684     Bosaso      SO  11.2842   49.1816     88.99        57         100
# 685     Talara      PE  -4.5772  -81.2719     74.16        64           0
#
#      Wind Speed Current Description
# 0         25.23     overcast clouds
# 1          3.00       broken clouds
# 2          3.44           clear sky
# 3          2.77     overcast clouds
# 4          7.76           clear sky
# ..          ...                 ...
# 681        2.01           clear sky
# 682        1.36          few clouds
# 683        8.99       broken clouds
# 684        3.67     overcast clouds
# 685       14.97           clear sky
#
# [686 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
